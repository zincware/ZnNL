# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

import jax
import znnl
from neural_tangents import stax
import copy
import optax

from flax import linen as nn
import flax
import jax.nn.initializers as inits

import matplotlib.pyplot as plt

import numpy as onp
import jax.numpy as np
# import time
import copy
# Out:
# 2023-09-23 19:12:38.798831: E external/xla/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 2023-09-23 19:12:44.592049: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using backend: cpu
# Available hardware:
# TFRT_CPU_0

# %% [markdown]
# # Including the trace regularization

# %%
from flax.training.train_state import TrainState
from znnl.training_strategies import SimpleTraining
from typing import Callable, List, Optional, Tuple, Union
from znnl.accuracy_functions.accuracy_function import AccuracyFunction
from znnl.models.jax_model import JaxModel
from znnl.training_strategies.recursive_mode import RecursiveMode

# %%
# def fun(a, params):
#     return jax.tree_util.tree_map(lambda x: x + a, params)

# params = model.model_state.params
# p = jax.vmap(fun, in_axes=(0, None))(np.arange(4), params)
# res = jax.vmap(model.apply, in_axes=(0, None))(p, data_generator.train_ds['inputs'][:10])
# # jax.tree_util.tree_map(lambda x: x.shape, p)
# np.shape(res)

# %%
# def _create_noise(params: dict, key):
#         """
#         Create a perturbation for the parameters.

#         Parameters
#         ----------
#         params : dict
#                 Parameters of the model.

#         Returns
#         -------
#         perturbation : dict
#                 Perturbation of the parameters.
#         """
#         noise = jax.tree_util.tree_map(lambda x: 0.1 * jax.random.normal(key, x.shape), params)
#         return noise


# def pert_apply(params, key):
#     """
#     helper grad computation

#     Returns
#     -------
#     ntk_trace_values : float, shape=(batch_size,)
#             Model predictions, averaged over the output dimension.
#     """
#     noise = _create_noise(params, key)
#     perturbed_params = jax.tree_util.tree_map(lambda x, y: x + y, params, noise)
#     perturbed_predictions = model.apply(perturbed_params, data_generator.train_ds["inputs"][:10])
#     return perturbed_predictions


# params = model.model_state.params
# keys = jax.random.split(jax.random.PRNGKey(0), num=8)
# # keys = np.arange(4)#[:, None]
# pred = jax.vmap(pert_apply, in_axes=(None, 0))(params, keys)
# np.shape(pred)

# %% [markdown]
# ## Raw code

# %%
class BlurredTraining(SimpleTraining):

    def __init__(
        self,
        model: Union[JaxModel, None],
        loss_fn: Callable,
        accuracy_fn: AccuracyFunction = None,
        seed: int = None,
        recursive_mode: RecursiveMode = None,
        disable_loading_bar: bool = False,
        recorders: List["JaxRecorder"] = None,
        blurr_radius: float = 1e-5, 
        integral_numbers: int = 10,
    ):
        """
        Construct a blurred training strategy for a model.

        The training is performed using a method to blurr the loss surface.

        Parameters
        ----------
        model : Union[JaxModel, None]
                Model class for a Jax model.
                "None" is only used if the training strategy is passed as an input
                to a bigger framework. The strategy then is applied to the framework
                and the model instantiation is handled by that framework.
        loss_fn : Callable
                A function to use in the loss computation.
        accuracy_fn : AccuracyFunction (default = None)
                Funktion class for computing the accuracy of model and given data.
        seed : int (default = None)
                Random seed for the RNG. Uses a random int if not specified.
        recursive_mode : RecursiveMode
                Defining the recursive mode that can be used in training.
                If the recursive mode is used, the training will be performed until a
                condition is fulfilled.
        disable_loading_bar : bool
                Disable the output visualization of the loading bar.
        recorders : List[JaxRecorder]
                A list of recorders to monitor model training.
        blurr_radios : float
                The blurr radius to use in the training.
        integral_numbers : int
                The number of random points to approximate the blurr integral.
        """
        super().__init__(
            model=model,
            loss_fn=loss_fn,
            accuracy_fn=accuracy_fn,
            seed=seed,
            recursive_mode=recursive_mode,
            disable_loading_bar=disable_loading_bar,
            recorders=recorders,
        )
        self.blurr_radius = blurr_radius
        self.integral_numbers = integral_numbers

    def _create_noise(self, params: dict, key, std: float):
        """
        Create noise for the parameters of the model. 

        Create Gaussian noise of Euclidean norm sampled from the the distribution:
        N(0, std)

        Parameters
        ----------
        params : dict
                Parameters of the model.
        key : jax.random.PRNGKey
                Key to sample the noise. 

        Returns
        -------
        noise : dict
                Noise dict of similar shape as the model parameters. 
        """

        noise = jax.tree_util.tree_map(lambda x: jax.random.normal(key, x.shape) * std * self.blurr_radius, params) 
        return noise
    
    def _create_noise_2(self, key: jax.random.PRNGKey, std: float):
        noise = self.model.model.init(key, np.ones(list(self.model.input_shape)))["params"] 
        return jax.tree_util.tree_map(lambda x: x * std * self.blurr_radius, noise)

    def _calculate_weighting_factor(self, noise_magnitude: float):
        """
        Calculate the weight factor corresponding to the applied noise. 

        Parameters
        ----------
        noise_magnitude : float
                Magnitude of the applied noise.

        Returns
        -------
        weight_factor : float
                Weight factor to apply to the loss function.
        """
        return np.exp(noise_magnitude ** 2 / 2 * self.blurr_radius ** 2)
    
                
    def _train_step(self, state: TrainState, batch: dict):
        """
        Train a single step.

        Parameters
        ----------
        state : TrainState
                Current state of the neural network.
        batch : dict
                Batch of data to train on.

        Returns
        -------
        state : dict
                Updated state of the neural network.
        metrics : dict
                Metrics for the current model.
        """
        
        def pert_apply(params, key, noise_magnitude):
            """
            Helper function to calculate a perturbed forward pass. 

            The computation is executed in the following steps:
            1. Create noise
            2. Add noise to parameters
            3. Evaluate the weight factor to apply to the loss
                The weight factor is applied to weight each perturbed prediction
                according to the magnitude of the noise.

            Parameters
            ----------
            params : dict
                    Parameters of the model.
            key : jax.random.PRNGKey
                    Key to sample the noise.

            Returns
            -------
            perturbed_predictions : float, shape=(batch_size, output_dim)
                     Perturbed model predictions.
            noise : dict
                     Noise applied to the parameters.
            """
            # Create noise 
        #     noise = self._create_noise(params, key, noise_magnitude)
            noise = self._create_noise_2(key, noise_magnitude)
            # Add noise to parameters to create perturbed parameters
            perturbed_params = jax.tree_util.tree_map(lambda x, y: x + y, params, noise)
            # Evaluate perturbed predictions
            perturbed_predictions = self.model.apply(perturbed_params, batch["inputs"])
        #     # Evaluate weight factor to scale the loss
        #     weight_factor = self._calculate_weighting_factor(noise_magnitude)
            return perturbed_predictions, noise

        def loss_fn(params):
            """
            helper loss computation
            """
            # Split the random key to create different noise for each integral number
            keys = jax.random.split(self.rng(), self.integral_numbers)
            noise_magnitudes = jax.random.normal(self.rng(), shape=(self.integral_numbers, ))
        #     noise_magnitudes = np.sign(noise_magnitudes) * np.sqrt(np.abs(noise_magnitudes))
        
            # Vmap the perturbed forward pass to create a batch of perturbed predictions
            pred, noise = jax.vmap(pert_apply, in_axes=(None, 0, 0))(params, keys, noise_magnitudes)

            # Compute the loss for each perturbed prediction
            losses = jax.vmap(self.loss_fn, in_axes=(0, None))(pred, batch["targets"])
            # Weight the losses according to the weight factors
            losses = losses * self._calculate_weighting_factor(noise_magnitudes)
            # Compute the mean loss and predictions
            predictions = np.mean(pred, axis=0)
            loss = np.mean(losses)
            return loss, predictions
        
        grad_fn = jax.value_and_grad(loss_fn, has_aux=True)

        (_, predictions), grads = grad_fn(state.params)
        state = state.apply_gradients(grads=grads)  # in place state update.
        metrics = self._compute_metrics(
            predictions=predictions, targets=batch["targets"]
        )

        return state, metrics

# %% [markdown]
# ## Code with Regularizer class

# %%
from abc import ABC

# %%
class Regularizer(ABC):
    """
    Parent class for all regularizers.
    """

    def __init__(self, reg_factor) -> None:
        """
        Constructor of the regularizer class.

        Parameters
        ----------
        reg_factor : float
                Regularization factor.
        """
        self.reg_factor = reg_factor
    
    def __call__(self, apply_fn, params, batch):
        """
        Call function of the regularizer class.

        Parameters
        ----------
        params : dict
                Parameters of the model.

        Returns
        -------
        reg_loss : float
                Regularization loss.
        """
        raise NotImplementedError
    

class TraceRegularizer(Regularizer):
    """
    Trace regularizer class.

    Regularizing gradient based learning with proportional to the trace of the NTK.
    As the trace of the NTK is calculated from the gradients of the model, the
    regularizer is implemented as a function of the gradients.
    """

    def __init__(self, reg_factor) -> None:
        super().__init__(reg_factor)    
    
    def __call__(self, apply_fn, params, batch):
        """
        Call function of the trace regularizer class.

        Parameters
        ----------
        grads : dict
                Gradients of the model.

        Returns
        -------
        reg_loss : float
                Regularization loss.
        """

        def grad_helper_fn(params):
            """
            helper grad computation

            Returns
            -------
            ntk_trace_values : float, shape=(batch_size,)
                    Model predictions, averaged over the output dimension.
            """
            traced_predictions = apply_fn(params, batch["inputs"])
            return traced_predictions  

        # Compute gradient of shape=(batch_size, n_outputs, params)
        grad = jax.jacrev(grad_helper_fn)(params)
        # Compute squared gradient of shape=(batch_size, n_outputs, params)
        grad_square = jax.tree_util.tree_map(lambda x: x ** 2, grad)
        # Average over all axes except the batch axis.
        idx_tree = jax.tree_util.tree_map(lambda x: tuple(range(1, len(x.shape))), grad_square)
        grad_sum = jax.tree_util.tree_map(lambda x, y: np.mean(x, axis=y), grad_square, idx_tree)
        # Add regularization term to loss.
        reg_loss = self.reg_factor * jax.flatten_util.ravel_pytree(grad_sum)[0].mean()
        return reg_loss


class GradRegularizer(Regularizer):
    """
    Grad regularizer class.

    Regularizing gradient based learning with proportional to the gradient of each 
    sample.
    """
    def __init__(self, reg_factor) -> None:
        super().__init__(reg_factor)    
    
    def __call__(self, apply_fn, params, batch):
        """
        Call function of the trace regularizer class.

        Parameters
        ----------
        grads : dict
                Gradients of the model.

        Returns
        -------
        reg_loss : float
                Regularization loss.
        """

        def grad_helper_fn(params):
            """
            helper grad computation

            Returns
            -------
            ntk_trace_values : float, shape=(batch_size,)
                    Model predictions, averaged over the output dimension.
            """
            averaged_predictions = apply_fn(params, batch["inputs"]).mean()
            return averaged_predictions  

        # Compute gradient of shape=(batch_size, n_outputs, params)
        grad = jax.grad(grad_helper_fn)(params)
        # Compute squared gradient of shape=(batch_size, n_outputs, params)
        grad_sum = jax.tree_util.tree_map(lambda x: np.mean(x ** 2), grad)
        reg_loss = self.reg_factor * jax.flatten_util.ravel_pytree(grad_sum)[0].mean()
        return reg_loss


class NormRegularizer(Regularizer):
    """
    Class to regularize on the norm of the parameters.

    Regularizing training using the norm of the parameters.
    Any function can be used that takes the parameters as input and returns a scalar.
    """
    def __init__(self, reg_factor: float = 1e-2, norm_fn: Optional[Callable] = None) -> None:
        """
        Constructor of the regularizer class.

        Parameters
        ----------
        reg_factor : float
                Regularization factor.
        norm_fn : Callable
                Function to compute the norm of the parameters.
        """
        super().__init__(reg_factor)
        self.norm_fn = norm_fn
        if self.norm_fn is None:
            self.norm_fn = lambda x: np.mean(x ** 2)
    
    def __call__(self, apply_fn, params, batch):
        """
        Call function of the trace regularizer class.

        Parameters
        ----------
        grads : dict
                Gradients of the model.

        Returns
        -------
        reg_loss : float
                Regularization loss.
        """
        # Compute squared gradient of shape=(batch_size, n_outputs, params)
        param_average = jax.tree_util.tree_map(lambda x: self.norm_fn(x), params)
        reg_loss = self.reg_factor * jax.flatten_util.ravel_pytree(param_average)[0].mean()
        return reg_loss

# %%
class RegularizedTraining(SimpleTraining):

    def __init__(
        self,
        model: Union[JaxModel, None],
        loss_fn: Callable,
        accuracy_fn: AccuracyFunction = None,
        seed: int = None,
        recursive_mode: RecursiveMode = None,
        disable_loading_bar: bool = False,
        recorders: List["JaxRecorder"] = None,
        regulizer: Regularizer = None,
    ):
        """
        Construct a simple training strategy for a model.

        Parameters
        ----------
        model : Union[JaxModel, None]
                Model class for a Jax model.
                "None" is only used if the training strategy is passed as an input
                to a bigger framework. The strategy then is applied to the framework
                and the model instantiation is handled by that framework.
        loss_fn : Callable
                A function to use in the loss computation.
        accuracy_fn : AccuracyFunction (default = None)
                Funktion class for computing the accuracy of model and given data.
        seed : int (default = None)
                Random seed for the RNG. Uses a random int if not specified.
        recursive_mode : RecursiveMode
                Defining the recursive mode that can be used in training.
                If the recursive mode is used, the training will be performed until a
                condition is fulfilled.
        disable_loading_bar : bool
                Disable the output visualization of the loading bar.
        recorders : List[JaxRecorder]
                A list of recorders to monitor model training.
        regularizer : Regularizer
                Regularizer class for including a regularizer in the training.
        """
        super().__init__(
            model=model,
            loss_fn=loss_fn,
            accuracy_fn=accuracy_fn,
            seed=seed,
            recursive_mode=recursive_mode,
            disable_loading_bar=disable_loading_bar,
            recorders=recorders,
        )
        self.regularizer = regulizer

                
    def _train_step(self, state: TrainState, batch: dict):
        """
        Train a single step.

        Parameters
        ----------
        state : TrainState
                Current state of the neural network.
        batch : dict
                Batch of data to train on.

        Returns
        -------
        state : dict
                Updated state of the neural network.
        metrics : dict
                Metrics for the current model.
        """

        def loss_fn(params):
            """
            helper loss computation
            """
            inner_predictions = self.model.apply(params, batch["inputs"])
            loss = self.loss_fn(inner_predictions, batch["targets"])

            # Add gradient regularization
            if self.regularizer:
                reg_loss = self.regularizer(self.model.apply, params, batch)
                loss += reg_loss
            return loss, inner_predictions
        
        grad_fn = jax.value_and_grad(loss_fn, has_aux=True)

        (_, predictions), grads = grad_fn(state.params)

        state = state.apply_gradients(grads=grads)  # in place state update.
        metrics = self._compute_metrics(
            predictions=predictions, targets=batch["targets"]
        )

        return state, metrics

# %% [markdown]
# # Set up Model

# %%
data_generator = znnl.data.MNISTGenerator(ds_size=50)

# %%
class Network(nn.Module):
    """
    Simple CNN module.
    """
    @nn.compact
    def __call__(self, x):        
        x = x.reshape((x.shape[0], -1))  # flatten
        
        x = nn.Dense(features=128)(x)
        x = nn.relu(x)
        
        x = nn.Dense(features=128)(x)
        x = nn.relu(x)
        x = nn.Dense(10)(x)
        return x

# %%
model = znnl.models.FlaxModel(
        flax_module=Network(),
        optimizer=optax.adam(learning_rate=0.01),
        input_shape=(1, 28, 28, 1),
        seed=0, 
    )

train_recorder = znnl.training_recording.JaxRecorder(
    name="train_recorder",
    loss=True,
    # ntk=True,
    # entropy= True, 
    # trace=True,
    # loss_derivative=True,
    update_rate=1, 
    chunk_size=1000
)
train_recorder.instantiate_recorder(
    data_set=data_generator.train_ds
)


test_recorder = znnl.training_recording.JaxRecorder(
    name="test_recorder",
    loss=True,
    update_rate=1,
    chunk_size=1000
)
test_recorder.instantiate_recorder(
    data_set=data_generator.test_ds
)

# %% [markdown]
# # Execute training

# %%
trainer = BlurredTraining(
    model=model, 
    loss_fn=znnl.loss_functions.CrossEntropyLoss(),
    accuracy_fn=znnl.accuracy_functions.LabelAccuracy(), 
    recorders=[train_recorder, test_recorder],  
    seed=0,
    blurr_radius=1e-3, 
    integral_numbers=100
)

# %%
batched_training_metrics = trainer.train_model(
    train_ds=data_generator.train_ds, 
    test_ds=data_generator.test_ds,
    batch_size=32,
    epochs=100,
)
# Out:
# Epoch: 100: 100%|███████████████████████████████| 100/100 [00:13<00:00,  7.69batch/s, accuracy=0.16]

# %%
train_report = train_recorder.gather_recording()
test_report = test_recorder.gather_recording()

# %%
plt.plot(train_report.loss, 'o', mfc='None', label="Train")
plt.plot(test_report.loss, 'o', mfc='None', label="Test")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.yscale("log")
plt.legend()
plt.show()

# %%
plt.plot(train_report.entropy, 'o', mfc='None', label="Entropy")
plt.xlabel("Epoch")
plt.ylabel("Entropy")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/konstantinnikolaou/PycharmProjects/ZnRND/examples/Blurred-Training.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/konstantinnikolaou/PycharmProjects/ZnRND/examples/Blurred-Training.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(train_report.entropy, 'o', mfc='None', label="Entropy")
#       <a href='vscode-notebook-cell:/Users/konstantinnikolaou/PycharmProjects/ZnRND/examples/Blurred-Training.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> plt.xlabel("Epoch")
#       <a href='vscode-notebook-cell:/Users/konstantinnikolaou/PycharmProjects/ZnRND/examples/Blurred-Training.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> plt.ylabel("Entropy")
#
# AttributeError: 'DataSet' object has no attribute 'entropy'

# %%
plt.plot(train_report.trace, 'o', mfc='None', label="Trace")
plt.xlabel("Epoch")
plt.ylabel("Trace")
plt.legend()
plt.show()

# %% [markdown]
# # Perform quick study

# %%
data_generator = znnl.data.CIFAR10Generator(ds_size=500)
data_generator.train_ds["inputs"] = data_generator.train_ds["inputs"][:50]
data_generator.train_ds["targets"] = data_generator.train_ds["targets"][:50]

# %%
class Network(nn.Module):
    """
    Simple CNN module.
    """
    @nn.compact
    def __call__(self, x):        
        x = x.reshape((x.shape[0], -1))  # flatten
        
        x = nn.Dense(features=512)(x)
        x = nn.relu(x)
        
        x = nn.Dense(features=512)(x)
        x = nn.relu(x)
        x = nn.Dense(10)(x)
        return x

# %%
def perform_quick_study(trainer_module: SimpleTraining, trainer_kwargs: dict, key: int, lr: float):


    model_key, trainer_key = jax.random.split(jax.random.PRNGKey(key), 2)
    model = znnl.models.FlaxModel(
        flax_module=Network(),
        optimizer=optax.sgd(learning_rate=lr),
        input_shape=(1, 32, 32, 3),
        seed=model_key[0], 
    )

    train_recorder = znnl.training_recording.JaxRecorder(
        name="train_recorder",
        loss=True,
        accuracy=True,
        # ntk=True,
        # entropy= True, 
        # trace=True,
        # loss_derivative=True,
        update_rate=1, 
        chunk_size=1000
    )
    train_recorder.instantiate_recorder(
        data_set=data_generator.train_ds
    )


    test_recorder = znnl.training_recording.JaxRecorder(
        name="test_recorder",
        loss=True,
        accuracy=True,
        update_rate=1,
        chunk_size=1000
    )
    test_recorder.instantiate_recorder(
        data_set=data_generator.test_ds
    )

    trainer = trainer_module(
        **trainer_kwargs,
        recorders=[train_recorder, test_recorder],  
        seed=trainer_key[0],
        model=model,
    )

    batched_training_metrics = trainer.train_model(
        train_ds=data_generator.train_ds, 
        test_ds=data_generator.test_ds,
        batch_size=32,
        epochs=300,
    )

    train_report = train_recorder.gather_recording()
    test_report = test_recorder.gather_recording()

    return train_report, test_report

# %%
simple_kwargs = {
    "loss_fn": znnl.loss_functions.CrossEntropyLoss(),
    "accuracy_fn": znnl.accuracy_functions.LabelAccuracy(), 
}

def get_blurred_kwargs(blurr_radius):
    blurred_training = {
        "loss_fn": znnl.loss_functions.CrossEntropyLoss(),
        "accuracy_fn": znnl.accuracy_functions.LabelAccuracy(), 
        "blurr_radius": blurr_radius, 
        "integral_numbers": 200,
    }
    return blurred_training


# blurr_radia = [0.16, 0.14, 0.12, 0.1, 0.09] 
# blurr_radia = [0.16, 0.14, 0.12, 0.1, 0.08] # non-sqrt
blurr_radia = [0.1, 0.2, 0.4, 0.6, 0.8] # sqrt
lrs = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
trainers = [simple_kwargs] + [get_blurred_kwargs(rad) for rad in blurr_radia]

# %%
# Execute a quick study

train_report_simple, test_report_simple = perform_quick_study(SimpleTraining, trainers[0], 0, lrs[0])
train_report_blurred_1, test_report_blurred_1 = perform_quick_study(BlurredTraining, trainers[1], 0, lrs[1])
train_report_blurred_2, test_report_blurred_2 = perform_quick_study(BlurredTraining, trainers[2], 0, lrs[2])
train_report_blurred_3, test_report_blurred_3 = perform_quick_study(BlurredTraining, trainers[3], 0, lrs[3])
train_report_blurred_4, test_report_blurred_4 = perform_quick_study(BlurredTraining, trainers[4], 0, lrs[4])
train_report_blurred_5, test_report_blurred_5 = perform_quick_study(BlurredTraining, trainers[5], 0, lrs[5])
# Out:
# Epoch: 300: 100%|██████████████████████████████| 300/300 [00:06<00:00, 45.21batch/s, accuracy=0.244]
# Epoch: 300: 100%|██████████████████████████████| 300/300 [18:58<00:00,  3.79s/batch, accuracy=0.242]
# Epoch: 300: 100%|██████████████████████████████| 300/300 [19:05<00:00,  3.82s/batch, accuracy=0.244]
# Epoch: 300: 100%|██████████████████████████████| 300/300 [19:06<00:00,  3.82s/batch, accuracy=0.252]
# Epoch: 300: 100%|██████████████████████████████| 300/300 [19:14<00:00,  3.85s/batch, accuracy=0.252]
# Epoch: 300: 100%|██████████████████████████████| 300/300 [19:23<00:00,  3.88s/batch, accuracy=0.176]

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5), tight_layout=True)

axs[0].plot(train_report_simple.loss, '-', label="Simple")
axs[0].plot(train_report_blurred_1.loss, '-', label=rf"Blurred $r = {blurr_radia[0]}$")
axs[0].plot(train_report_blurred_2.loss, '-', label=rf"Blurred $r = {blurr_radia[1]}$")
axs[0].plot(train_report_blurred_3.loss, '-', label=rf"Blurred $r = {blurr_radia[2]}$")
axs[0].plot(train_report_blurred_4.loss, '-', label=rf"Blurred $r = {blurr_radia[3]}$")
# axs[0].plot(train_report_blurred_5.loss, '-', label=rf"Blurred $r = {blurr_radia[4]}$")

axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Train Loss")
axs[0].set_yscale("log")
axs[0].legend()

axs[1].plot(test_report_simple.loss, '-', label="Simple")
axs[1].plot(test_report_blurred_1.loss, '-', label=rf"Blurred $r = {blurr_radia[0]}$")
axs[1].plot(test_report_blurred_2.loss, '-', label=rf"Blurred $r = {blurr_radia[1]}$")
axs[1].plot(test_report_blurred_3.loss, '-', label=rf"Blurred $r = {blurr_radia[2]}$")
axs[1].plot(test_report_blurred_4.loss, '-', label=rf"Blurred $r = {blurr_radia[3]}$")
# axs[1].plot(test_report_blurred_5.loss, '-', label=rf"Blurred $r = {blurr_radia[4]}$")

axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Test Loss")
axs[1].set_yscale("log")

axs[2].plot(test_report_simple.accuracy, '-', label="Simple")
axs[2].plot(test_report_blurred_1.accuracy, '-', label=rf"Blurred $r = {blurr_radia[0]}$")
axs[2].plot(test_report_blurred_2.accuracy, '-', label=rf"Blurred $r = {blurr_radia[1]}$")
axs[2].plot(test_report_blurred_3.accuracy, '-', label=rf"Blurred $r = {blurr_radia[2]}$")
axs[2].plot(test_report_blurred_4.accuracy, '-', la1bel=rf"Blurred $r = {blurr_radia[3]}$")
# axs[2].plot(test_report_blurred_5.accuracy, '-', label=rf"Blurred $r = {blurr_radia[4]}$")
# axs[2].set_ylim([0.65, 0.75])

axs[2].set_xlabel("Epoch")
axs[2].set_ylabel("Test Accuracy")
# axs[2].set_yscale("log")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[351], line 30
#      28 axs[2].plot(test_report_blurred_2.accuracy, '-', label=rf"Blurred $r = {blurr_radia[1]}$")
#      29 axs[2].plot(test_report_blurred_3.accuracy, '-', label=rf"Blurred $r = {blurr_radia[2]}$")
# ---> 30 axs[2].plot(test_report_blurred_4.accuracy, '-', la1bel=rf"Blurred $r = {blurr_radia[3]}$")
#      31 # axs[2].plot(test_report_blurred_5.accuracy, '-', label=rf"Blurred $r = {blurr_radia[4]}$")
#      32 # axs[2].set_ylim([0.65, 0.75])
#      34 axs[2].set_xlabel("Epoch")
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/axes/_base.py:544, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     542     return list(result)
#     543 else:
# --> 544     return [l[0] for l in result]
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/axes/_base.py:544, in <listcomp>(.0)
#     542     return list(result)
#     543 else:
# --> 544     return [l[0] for l in result]
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/axes/_base.py:537, in <genexpr>(.0)
#     534 else:
#     535     labels = [label] * n_datasets
# --> 537 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     538                       {**kwargs, 'label': label})
#     539           for j, label in enumerate(labels))
#     541 if return_kwargs:
#     542     return list(result)
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/axes/_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/lines.py:395, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391 self.set_markeredgewidth(markeredgewidth)
#     393 # update kwargs before updating data to give the caller a
#     394 # chance to init axes (and hence unit support)
# --> 395 self._internal_update(kwargs)
#     396 self._pickradius = pickradius
#     397 self.ind_offset = 0
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/miniconda3/envs/jax_gpu/lib/python3.10/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'la1bel'

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5), tight_layout=True)

axs[0].plot(train_report_simple.trace, '-', label="Simple")
axs[0].plot(train_report_blurred_1.trace, '-', label=rf"Blurred $r = {blurr_radia[0]}$")
axs[0].plot(train_report_blurred_2.trace, '-', label=rf"Blurred $r = {blurr_radia[1]}$")
axs[0].plot(train_report_blurred_3.trace, '-', label=rf"Blurred $r = {blurr_radia[2]}$")
axs[0].plot(train_report_blurred_4.trace, '-', label=rf"Blurred $r = {blurr_radia[3]}$")
axs[0].plot(train_report_blurred_5.trace, '-', label=rf"Blurred $r = {blurr_radia[4]}$")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Trace")
axs[0].legend()

axs[1].plot(train_report_simple.entropy, '-', label="Simple")
axs[1].plot(train_report_blurred_1.entropy, '-', label=rf"Blurred $r = {blurr_radia[0]}$")
axs[1].plot(train_report_blurred_2.entropy, '-', label=rf"Blurred $r = {blurr_radia[1]}$")
axs[1].plot(train_report_blurred_3.entropy, '-', label=rf"Blurred $r = {blurr_radia[2]}$")
axs[1].plot(train_report_blurred_4.entropy, '-', label=rf"Blurred $r = {blurr_radia[3]}$")
axs[1].plot(train_report_blurred_5.entropy, '-', label=rf"Blurred $r = {blurr_radia[4]}$")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Entropy")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[249], line 3
#       1 fig, axs = plt.subplots(1, 2, figsize=(15, 5), tight_layout=True)
# ----> 3 axs[0].plot(train_report_simple.trace, '-', label="Simple")
#       4 axs[0].plot(train_report_blurred_1.trace, '-', label=rf"Blurred $r = {blurr_radia[0]}$")
#       5 axs[0].plot(train_report_blurred_2.trace, '-', label=rf"Blurred $r = {blurr_radia[1]}$")
#
# AttributeError: 'DataSet' object has no attribute 'trace'
